# %% [markdown]
# # ETL Pipeline — Master Orchestrator
#
# Runs the full extract → transform → load pipeline.
# Add new datasets by repeating the three-step pattern below.

# %%
import subprocess, sys

# Run each ETL step as a notebook so outputs are preserved
subprocess.run([sys.executable, "-m", "jupyter", "nbconvert", "--to", "notebook",
                "--execute", "01_extract.ipynb", "--output", "01_extract.ipynb"], check=True)
subprocess.run([sys.executable, "-m", "jupyter", "nbconvert", "--to", "notebook",
                "--execute", "02_transform.ipynb", "--output", "02_transform.ipynb"], check=True)
subprocess.run([sys.executable, "-m", "jupyter", "nbconvert", "--to", "notebook",
                "--execute", "03_load.ipynb", "--output", "03_load.ipynb"], check=True)

print("Pipeline complete.")
